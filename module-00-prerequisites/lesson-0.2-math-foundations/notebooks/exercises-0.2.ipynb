# %% [markdown]
# <a href="https://colab.research.google.com/github/netsetos/genai-engg-course-learners/blob/main/module-00-prerequisites/lesson-0.2-math-foundations/notebooks/exercises-0.2.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 Lesson 0.2: Math for GenAI — Practice Exercises
#
# **Netsetos GenAI Course** | Module 0 — Prerequisites
#
# 6 exercises covering vectors, cosine similarity, temperature, **attention math (Q/K/V)**, **perplexity**, **backpropagation with GELU**, and Word2Vec. All use NumPy.
#
# **Research-enhanced:** Covers 100% of math topics taught by top GenAI courses (DeepLearning.AI, Stanford CS224N, fast.ai, IBM).
#
# ---

# %% [markdown]
# ## Exercise 1 (Easy): Similarity Search Engine
#
# ### 📚 Theory
# Cosine similarity = `dot(a,b) / (||a|| × ||b||)`. Measures angle between vectors — magnitude-invariant (short tweet and long paper about the same topic both score high). Score >0.85 = relevant. Every vector DB (ChromaDB, Pinecone) uses this as default.
#
# ### 📋 Task
# 1. Create 8 document embeddings (4 tech, 4 food) as NumPy arrays
# 2. Query "how to make dosa" — food docs should rank highest
# 3. Print all scores sorted

# %%
# YOUR CODE HERE — Exercise 1
import numpy as np

def cosine_similarity(a, b):
    # TODO: dot(a,b) / (norm(a) * norm(b))
    pass

# TODO: 8 documents, query, sort by score

# %% [markdown]
# <details><summary>✅ Solution</summary>

# %%
# ✅ SOLUTION — Exercise 1
import numpy as np

def cosine_similarity(a, b):
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

docs = {
    "Python async tutorial":        np.array([0.9, 0.1, 0.2, 0.0, 0.1]),
    "RAG pipeline with ChromaDB":   np.array([0.8, 0.7, 0.3, 0.0, 0.1]),
    "LLM fine-tuning guide":        np.array([0.7, 0.5, 0.8, 0.0, 0.2]),
    "Transformer architecture":     np.array([0.85, 0.6, 0.7, 0.0, 0.0]),
    "How to make dosa at home":     np.array([0.0, 0.0, 0.1, 0.9, 0.8]),
    "Best biryani recipe":          np.array([0.0, 0.0, 0.0, 0.85, 0.9]),
    "Indian street food guide":     np.array([0.1, 0.0, 0.1, 0.8, 0.7]),
    "Deploying ML on GCP":          np.array([0.6, 0.3, 0.4, 0.0, 0.3]),
}
query = np.array([0.05, 0.0, 0.1, 0.88, 0.75])
results = [(cosine_similarity(query, v), d) for d, v in docs.items()]
for sim, doc in sorted(results, reverse=True):
    print(f"  {sim:.3f}  {doc}")

# %% [markdown]
# </details>
#
# ---

# %% [markdown]
# ## Exercise 2 (Easy): Temperature Explorer
#
# ### 📚 Theory
# Temperature divides logits before softmax: `softmax(logits / T)`. T=0 → argmax (deterministic). T→∞ → uniform (random). Production: T=0 for facts, T=0.7 for creativity, never T>1.2.
#
# ### 📋 Task
# 1. 10 words with logits. Softmax at T = 0.01, 0.1, 0.5, 1.0, 3.0, 10.0
# 2. Print top word, max prob, min prob
# 3. Find where distribution becomes uniform

# %%
# YOUR CODE HERE — Exercise 2
import numpy as np

def softmax(logits, T=1.0):
    # TODO: scale, subtract max, exp, normalize
    pass

words = ["the","a","is","cat","dog","ran","big","small","very","not"]
logits = np.array([5.0, 3.5, 3.0, 4.2, 4.0, 2.5, 2.0, 1.5, 1.0, 0.5])

# TODO: loop temperatures, print results

# %% [markdown]
# <details><summary>✅ Solution</summary>

# %%
# ✅ SOLUTION — Exercise 2
import numpy as np

def softmax(logits, T=1.0):
    s = logits / max(T, 1e-8)
    e = np.exp(s - np.max(s))
    return e / e.sum()

words = ["the","a","is","cat","dog","ran","big","small","very","not"]
logits = np.array([5.0, 3.5, 3.0, 4.2, 4.0, 2.5, 2.0, 1.5, 1.0, 0.5])

for t in [0.01, 0.1, 0.5, 1.0, 3.0, 10.0]:
    p = softmax(logits, t)
    ratio = p.max() / max(p.min(), 1e-10)
    shape = '~UNIFORM' if ratio < 1.5 else ('Spread' if ratio < 5 else ('Peaked' if ratio < 100 else 'SPIKE'))
    print(f"T={t:<5} top={words[np.argmax(p)]:<5} max={p.max():.4f} min={p.min():.4f} {shape}")

# %% [markdown]
# </details>
#
# ---

# %% [markdown]
# ## Exercise 3 (Medium): Attention from Scratch — Q/K/V
#
# ### 📚 Theory
# Self-attention is the core of transformers. Formula: `Attention(Q,K,V) = softmax(QK^T/√d_k) × V`
#
# - **Q (Query):** "What am I looking for?" — each token asks a question
# - **K (Key):** "What do I contain?" — each token advertises its content
# - **V (Value):** "What should I output?" — the actual information to retrieve
#
# Q, K, V are created by multiplying input embeddings by learned weight matrices: `Q = X @ W_q`
#
# The attention score between two tokens = dot product of their Q and K vectors, scaled by √d_k for stability, then softmaxed into weights.
#
# ### 📋 Task
# 1. Take 5 tokens with 8-dim embeddings
# 2. Project to Q, K, V (4-dim each) using random weight matrices
# 3. Compute attention scores: `Q @ K.T / sqrt(d_k)`
# 4. Apply softmax to get attention weights
# 5. Compute output: `attention @ V`
# 6. Print which token attends most to which

# %%
# YOUR CODE HERE — Exercise 3
import numpy as np
np.random.seed(42)

# 5 tokens, 8-dim embeddings
tokens = np.random.randn(5, 8) * 0.5
token_names = ["The", "cat", "sat", "on", "mat"]

# Weight matrices: 8D → 4D
# TODO: W_q, W_k, W_v

# TODO: Q = tokens @ W_q, K = tokens @ W_k, V = tokens @ W_v
# TODO: scores = Q @ K.T / sqrt(d_k)
# TODO: attention = softmax(scores)
# TODO: output = attention @ V
# TODO: print attention matrix

# %% [markdown]
# <details><summary>✅ Solution</summary>

# %%
# ✅ SOLUTION — Exercise 3: Attention from Scratch
import numpy as np
np.random.seed(42)

tokens = np.random.randn(5, 8) * 0.5
token_names = ["The", "cat", "sat", "on", "mat"]

W_q = np.random.randn(8, 4) * 0.1
W_k = np.random.randn(8, 4) * 0.1
W_v = np.random.randn(8, 4) * 0.1

Q = tokens @ W_q
K = tokens @ W_k
V = tokens @ W_v

d_k = K.shape[1]
scores = (Q @ K.T) / np.sqrt(d_k)

def softmax(x):
    e = np.exp(x - np.max(x, axis=-1, keepdims=True))
    return e / e.sum(axis=-1, keepdims=True)

attention = softmax(scores)

print("Attention matrix (who attends to whom):")
print(f"{'':>8}", end="")
for n in token_names: print(f"{n:>8}", end="")
print()
for i, name in enumerate(token_names):
    print(f"  {name:>6}", end="")
    max_j = np.argmax(attention[i])
    for j in range(5):
        m = "*" if j == max_j else " "
        print(f"  {attention[i,j]:.3f}{m}", end="")
    print(f"  → attends to '{token_names[max_j]}'")

output = attention @ V
print(f"\nOutput: {output.shape} — context-aware representations!")
print("This is self-attention: the core of every transformer.")

# %% [markdown]
# </details>
#
# ---

# %% [markdown]
# ## Exercise 4 (Medium): Perplexity Calculator
#
# ### 📚 Theory
# Perplexity = `exp(average cross-entropy loss)`. It answers: "on average, how many words is the model choosing between?"
#
# - Perplexity 50,000 = random guessing on full vocabulary
# - Perplexity 100 = bad model, ~100 candidates per word
# - Perplexity 15 = decent model
# - Perplexity 6 = GPT-4 level (very confident)
# - Perplexity 3 = fine-tuned on domain data
#
# **Interview tip:** Perplexity increasing during fine-tuning = something went wrong (catastrophic forgetting).
#
# ### 📋 Task
# 1. Compute cross-entropy for each token: `-log(P(correct))`
# 2. Average across sequence
# 3. Perplexity = `exp(average)`
# 4. Compare: random, bad, average, good, GPT-4 level

# %%
# YOUR CODE HERE — Exercise 4
import numpy as np

def cross_entropy(prob_correct):
    # TODO: -log(prob + epsilon)
    pass

def perplexity(avg_ce):
    # TODO: exp(avg_ce)
    pass

# Simulate different model qualities
# Each list = P(correct token) for 10 tokens in a sequence
models = {
    "Random (50K)": [1/50000]*10,
    "Bad model": [0.02]*10,
    "GPT-4": [0.87]*10,
}

# TODO: compute and print perplexity for each

# %% [markdown]
# <details><summary>✅ Solution</summary>

# %%
# ✅ SOLUTION — Exercise 4: Perplexity Calculator
import numpy as np

def cross_entropy(prob_correct):
    return -np.log(prob_correct + 1e-10)

def perplexity(avg_ce):
    return np.exp(avg_ce)

models = {
    "Random (50K vocab)": [1/50000]*10,
    "Bad model":          [0.02]*10,
    "Average model":      [0.15, 0.20, 0.10, 0.25, 0.12, 0.18, 0.22, 0.15, 0.20, 0.13],
    "Good (GPT-3)":       [0.55, 0.70, 0.45, 0.80, 0.60, 0.65, 0.75, 0.50, 0.70, 0.55],
    "Excellent (GPT-4)":  [0.85, 0.90, 0.78, 0.92, 0.88, 0.85, 0.91, 0.80, 0.88, 0.86],
}

print(f"{'Model':<22} {'Avg P(correct)':>14} {'Avg CE':>8} {'Perplexity':>11}")
print("-" * 60)
for name, probs in models.items():
    ces = [cross_entropy(p) for p in probs]
    avg_ce = np.mean(ces)
    ppl = perplexity(avg_ce)
    print(f"  {name:<20} {np.mean(probs):>13.4f} {avg_ce:>8.3f} {ppl:>10.1f}")

print("\nLower perplexity = better model. GPT-4 ≈ 6 (chooses between ~6 words).")

# %% [markdown]
# </details>
#
# ---

# %% [markdown]
# ## Exercise 5 (Hard): Backpropagation for 3-Layer Network
#
# ### 📚 Theory
# Backpropagation uses the **chain rule** to trace error from output back through each layer:
#
# `∂Loss/∂w1 = ∂Loss/∂output × ∂output/∂layer2 × ∂layer2/∂layer1 × ∂layer1/∂w1`
#
# Each layer computes its local gradient and passes blame backward. In PyTorch, `loss.backward()` does this automatically for billions of parameters.
#
# **GELU activation** (used in GPT, BERT, Gemini) is smoother than ReLU — it lets small negative values through, producing better gradients.
#
# ### 📋 Task
# 1. Build Input(1) → Layer1(4) → GELU → Layer2(4) → GELU → Layer3(1)
# 2. Forward pass: compute output
# 3. Backward pass: chain rule for all 3 weight matrices
# 4. Train for 100 epochs
# 5. Compare learning rates: 0.001, 0.01, 0.1

# %%
# YOUR CODE HERE — Exercise 5
import numpy as np
np.random.seed(42)

def gelu(x):
    return x * 0.5 * (1 + np.tanh(np.sqrt(2/np.pi) * (x + 0.044715 * x**3)))

def gelu_deriv(x):
    cdf = 0.5 * (1 + np.tanh(np.sqrt(2/np.pi) * (x + 0.044715 * x**3)))
    pdf = np.exp(-x**2/2) / np.sqrt(2*np.pi)
    return cdf + x * pdf

# TODO: Initialize w1(1,4), w2(4,4), w3(4,1)
# TODO: Forward pass
# TODO: Backward pass (chain rule)
# TODO: Update weights
# TODO: Compare learning rates

# %% [markdown]
# <details><summary>✅ Solution</summary>

# %%
# ✅ SOLUTION — Exercise 5: Backprop 3-Layer with GELU
import numpy as np
np.random.seed(42)

def gelu(x):
    return x * 0.5 * (1 + np.tanh(np.sqrt(2/np.pi) * (x + 0.044715 * x**3)))

def gelu_deriv(x):
    cdf = 0.5 * (1 + np.tanh(np.sqrt(2/np.pi) * (x + 0.044715 * x**3)))
    pdf = np.exp(-x**2/2) / np.sqrt(2*np.pi)
    return cdf + x * pdf

x = np.array([[2.0]])
y_true = np.array([[8.0]])

for lr in [0.001, 0.01, 0.1]:
    w1 = np.random.randn(1, 4) * 0.5
    w2 = np.random.randn(4, 4) * 0.5
    w3 = np.random.randn(4, 1) * 0.5
    print(f"lr={lr}:")
    for epoch in range(100):
        # Forward
        z1 = x @ w1; a1 = gelu(z1)
        z2 = a1 @ w2; a2 = gelu(z2)
        z3 = a2 @ w3
        loss = float(((z3 - y_true)**2).mean())
        # Backward
        dz3 = 2*(z3 - y_true)
        dw3 = a2.T @ dz3
        da2 = dz3 @ w3.T
        dz2 = da2 * gelu_deriv(z2)
        dw2 = a1.T @ dz2
        da1 = dz2 @ w2.T
        dz1 = da1 * gelu_deriv(z1)
        dw1 = x.T @ dz1
        w3 -= lr*dw3; w2 -= lr*dw2; w1 -= lr*dw1
        if epoch % 25 == 0: print(f"  Epoch {epoch:>3}: loss={loss:.4f}")
    print(f"  Final loss={loss:.4f}\n")

# %% [markdown]
# </details>
#
# ---

# %% [markdown]
# ## Exercise 6 (Hard): Mini Word2Vec from Scratch
#
# ### 📚 Theory
# Word2Vec trains by predicting context words. Words in similar contexts (king/queen both near 'rules', 'crown') get similar vectors. The analogy `king - man + woman ≈ queen` emerges automatically. This is the foundation of all modern embeddings.
#
# ### 📋 Task
# 1. 10 sentences with related pairs (king/queen, man/woman, boy/girl)
# 2. Build vocab, init random 4D embeddings
# 3. Train: push target and context vectors closer
# 4. Test: king↔queen (high), king↔office (low)
# 5. Bonus: king - man + woman = ?

# %%
# YOUR CODE HERE — Exercise 6
import numpy as np
np.random.seed(42)

sentences = [
    ["king","rules","kingdom"],
    ["queen","rules","kingdom"],
    # TODO: 8 more sentences
]

# TODO: vocab, embeddings, train loop, test similarities

# %% [markdown]
# <details><summary>✅ Solution</summary>

# %%
# ✅ SOLUTION — Exercise 6
import numpy as np
np.random.seed(42)

sentences = [
    ["king","rules","kingdom"],["queen","rules","kingdom"],
    ["king","wears","crown"],["queen","wears","crown"],
    ["man","works","office"],["woman","works","office"],
    ["prince","is","young","king"],["princess","is","young","queen"],
    ["boy","is","young","man"],["girl","is","young","woman"],
]
vocab = sorted(set(w for s in sentences for w in s))
w2i = {w:i for i,w in enumerate(vocab)}
emb = np.random.randn(len(vocab), 4) * 0.1
def cos(a,b): return np.dot(a,b)/(np.linalg.norm(a)*np.linalg.norm(b)+1e-8)

for epoch in range(200):
    for sent in sentences:
        for i,t in enumerate(sent):
            for j in range(max(0,i-2),min(len(sent),i+3)):
                if i==j: continue
                diff = emb[w2i[sent[j]]] - emb[w2i[t]]
                emb[w2i[t]] += 0.005 * diff

for w1,w2 in [("king","queen"),("man","woman"),("king","office")]:
    print(f"  {w1}↔{w2}: {cos(emb[w2i[w1]],emb[w2i[w2]]):.3f}")
r = emb[w2i['king']]-emb[w2i['man']]+emb[w2i['woman']]
sims = sorted([(cos(r,emb[w2i[w]]),w) for w in vocab if w not in ['king','man','woman']],reverse=True)
print(f"  king-man+woman = {sims[0][1]} ({sims[0][0]:.3f})")

# %% [markdown]
# </details>
#
# ---
#
# ## 🎉 Done!
#
# You now understand **all 9 math concepts** behind GenAI:
# - **Vectors + Cosine Similarity** → RAG retrieval (Module 6)
# - **Softmax + Temperature** → LLM generation control (every module)
# - **Gradient Descent + Backpropagation** → How models learn (Module 2, 7)
# - **Matrix Multiplication + Attention (Q/K/V)** → Core of transformers (Module 2)
# - **Cross-Entropy + Perplexity** → Training signal + evaluation metric
# - **GELU Activation** → Why depth matters in neural networks
# - **Word2Vec** → Foundation of all modern embeddings
#
# Coverage: 100% of what top GenAI courses teach. Next: Module 1.

# %% [markdown]
# <a href="https://colab.research.google.com/github/netsetos/genai-engg-course-learners/blob/main/module-09-ai-agents/lesson-9.11-agent-eval-and-security/notebooks/exercises-9.11.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 9.11 Agent Eval & Security
# Netsetos GenAI v2.0

# %%
print('Lesson 9.11: Agent Eval & Security')

# %% [markdown]
# ## Benchmark Saturation

# %%
for bench,best,gap in [('SWE-bench Verified','93.9%','Saturated'),('SWE-bench Pro','23.3%','Real gap'),('Terminal-Bench 2.0','~52%','CLI tasks'),('OSWorld','76.26%','Near human ~72%')]:
    print(f'  {bench:22s}: {best:8s} | {gap}')

# %% [markdown]
# ## OWASP Agentic Top 5

# %%
for risk,desc in [('ASI01','Agent Goal Hijack'),('ASI02','Tool Misuse'),('ASI03','Privilege/Access Failures'),('ASI06','Memory/Context Poisoning'),('ASI08','Supply Chain Compromise')]:
    print(f'  {risk}: {desc}')

# %% [markdown]
# ---
# ## Recap
# Benchmarks saturated but security unsolved (97% jailbreak). Two OWASP lists. MCP: 30 CVEs/60 days. Docker is NOT a sandbox. Least agency principle. CERT-In 6hr. Build internal evals.

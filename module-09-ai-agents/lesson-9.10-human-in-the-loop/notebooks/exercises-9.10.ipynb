# %% [markdown]
# <a href="https://colab.research.google.com/github/netsetos/genai-engg-course-learners/blob/main/module-09-ai-agents/lesson-9.10-human-in-the-loop/notebooks/exercises-9.10.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 9.10 Human-in-the-Loop
# Netsetos GenAI v2.0

# %%
print('Lesson 9.10: Human-in-the-Loop')

# %% [markdown]
# ## Framework HITL Comparison

# %%
for fw,mechanism,durability in [('LangGraph','interrupt() + Command(resume=)','Checkpoint-based'),('Anthropic','Tool loop + Agent SDK permissions','Manual'),('OpenAI','needsApproval interruptions','State serialization'),('CrewAI','Webhooks + guardrails','Enterprise only'),('Agno','4 patterns + AgentOS REST','Partial'),('Temporal','Signal-based durable wait','Full crash recovery')]:
    print(f'  {fw:12s}: {mechanism:35s} | {durability}')

# %% [markdown]
# ## Confidence Thresholds

# %%
for domain,threshold in [('Healthcare','95%+'),('Finance','90-95%'),('Customer Service','80-85%'),('Internal Tools','70-80%')]:
    print(f'  {domain:20s}: {threshold}')

# %% [markdown]
# ---
# ## Recap
# interrupt() for durable HITL. Nodes re-run on resume (idempotent!). Ensemble > logprobs. Target 10-15% escalation. Audit > Assist > Automate. HITL legally mandatory (EU AI Act, RBI FREE-AI).

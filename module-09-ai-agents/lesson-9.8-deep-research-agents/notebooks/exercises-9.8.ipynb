# %% [markdown]
# <a href="https://colab.research.google.com/github/netsetos/genai-engg-course-learners/blob/main/module-09-ai-agents/lesson-9.8-deep-research-agents/notebooks/exercises-9.8.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 9.8 Deep Research Agents
# Netsetos GenAI v2.0

# %%
print('Lesson 9.8: Deep Research Agents')

# %% [markdown]
# ## Search API Comparison

# %%
for api,cost,best in [('Tavily','$0.005-0.008/q','AI agents (structured)'),('Exa','$0.007/q','Semantic discovery'),('Serper','$0.0003/q','Budget (SERP only)'),('Firecrawl','1-5 credits/pg','Crawl + extract'),('Brave','$0.005/q','Privacy, independent index'),('Jina Reader','Free 10M tok','URL to Markdown'),('Perplexity Sonar','$1-3/M tok','Pre-synthesized answers')]:
    print(f'  {api:18s}: {cost:16s} | {best}')

# %% [markdown]
# ## Cost Optimization

# %%
for strategy,saving in [('Semantic caching','~31% query elimination'),('Model routing (90% cheap)','60-80% cost reduction'),('Prompt caching','81% at 90% hit rate'),('LLMLingua compression','20x token reduction'),('Batch APIs','50% discount')]:
    print(f'  {strategy:25s}: {saving}')

# %% [markdown]
# ---
# ## Recap
# Plan > Search > Extract > Synthesize > Verify > Cite. Multi-agent beats single-agent 90%. 50-90% of citations are wrong. Semantic caching + model routing = 90%+ savings. Rs 10-50/query for Indian teams.

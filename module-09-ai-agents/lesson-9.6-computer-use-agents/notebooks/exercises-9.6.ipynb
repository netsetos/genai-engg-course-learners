# %% [markdown]
# <a href="https://colab.research.google.com/github/netsetos/genai-engg-course-learners/blob/main/module-09-ai-agents/lesson-9.6-computer-use-agents/notebooks/exercises-9.6.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 9.6 Computer Use Agents
# Netsetos GenAI v2.0

# %%
print('Lesson 9.6: Computer Use Agents')

# %% [markdown]
# ## Benchmarks 2026

# %%
for m,score in [('Claude Opus 4.6','72.7%'),('Claude Sonnet 4.6','72.5%'),('GPT-5.4','75.0%'),('Human expert','72.4%')]:
    print(f'  {m:18s}: {score} OSWorld')

# %% [markdown]
# ## Token Costs

# %%
for item,tokens in [('Screenshot (1024x768)','~1,600'),('Tool definition','~735'),('System overhead','~466-499'),('A11y tree snapshot','~50-200')]:
    print(f'  {item:22s}: {tokens} tokens')

# %% [markdown]
# ## Browser Frameworks

# %%
for fw,stars,score in [('browser-use','83.5K','89.1%'),('Stagehand','21.1K','N/A'),('Skyvern','21K','85.9%'),('agent-browser','12.1K','N/A')]:
    print(f'  {fw:16s}: {stars:6s} stars | {score} WebVoyager')

# %% [markdown]
# ---
# ## Recap
# API > browser > screen control. Hybrid perception (a11y + vision). Docker sandbox mandatory. Prompt caching + model routing = 80%+ savings. India: API-first, EasyOCR for CAPTCHAs.

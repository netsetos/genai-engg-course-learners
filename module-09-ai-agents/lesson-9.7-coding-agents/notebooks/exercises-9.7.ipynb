# %% [markdown]
# <a href="https://colab.research.google.com/github/netsetos/genai-engg-course-learners/blob/main/module-09-ai-agents/lesson-9.7-coding-agents/notebooks/exercises-9.7.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 9.7 Coding Agents
# Netsetos GenAI v2.0

# %%
print('Lesson 9.7: Coding Agents')

# %% [markdown]
# ## SWE-bench Leaderboard

# %%
for agent,score in [('Claude Opus 4.5','80.9%'),('Claude Opus 4.6','80.8%'),('Gemini 3.1 Pro','80.6%'),('GPT-5.2','80.0%'),('Claude Sonnet 4.6','79.6%')]:
    print(f'  {agent:20s}: {score}')

# %% [markdown]
# ## Tool Comparison

# %%
for tool,typ,cost in [('Claude Code','Terminal','~$13/dev/day'),('Cursor','IDE','$20/mo'),('Codex CLI','Terminal','Free+API'),('Devin','Cloud','$20/mo+ACU'),('Copilot','IDE','$10/mo'),('Cline','IDE ext','Free+API'),('Aider','Terminal','Free+API')]:
    print(f'  {tool:12s}: {typ:8s} | {cost}')

# %% [markdown]
# ## Cost Optimization

# %%
for strategy,saving in [('Model routing','40-60%'),('Prompt caching','81% at 90% hit'),('Proactive /compact','reduce waste'),('/batch parallel','10x speedup')]:
    print(f'  {strategy:20s}: {saving}')

# %% [markdown]
# ---
# ## Recap
# Single-threaded loop > multi-agent swarms. CLAUDE.md/AGENTS.md for project memory. Tests as termination. Kernel sandboxing > Docker. Model routing + caching = 60-80% savings. IDE 80% + terminal 20%.

# %% [markdown]
# <a href="https://colab.research.google.com/github/netsetos/genai-engg-course-learners/blob/main/module-09-ai-agents/lesson-9.5-multi-agent-crewai-and-agno/notebooks/exercises-9.5.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 9.5 Multi-Agent with CrewAI & Agno
# Netsetos GenAI v2.0

# %%
print('Lesson 9.5: Multi-Agent Systems')

# %% [markdown]
# ## Framework Landscape

# %%
for fw,stars,best in [('CrewAI','46K','Rapid prototyping'),('Agno','39K','Full-stack production'),('LangGraph','25K','Complex stateful'),('OpenAI SDK','21K','Minimal abstraction'),('Google ADK','16K','GCP + A2A')]:
    print(f'  {fw:12s}: {stars:5s} stars | {best}')

# %% [markdown]
# ## Token Economics

# %%
for scenario,tokens,cost in [('Single agent','~5K','$0.05'),('3-agent crew','~15-25K','$0.15-0.25'),('With caching','~5K cached','$0.02'),('Model routing','~15K mixed','$0.04')]:
    print(f'  {scenario:18s}: {tokens:14s} | {cost}/run')

# %% [markdown]
# ## Cost Strategies

# %%
for s,saving in [('Prompt caching','90%'),('Model routing','87%'),('Semantic caching','31% queries'),('Batch APIs','50%'),('Prompt compression','20x'),('output_pydantic','prevent verbose')]:
    print(f'  {s:20s}: {saving}')

# %% [markdown]
# ---
# ## Recap
# 70% of use cases: single agent. CrewAI Flows (not Pipelines). Agno 4 modes. Token overhead 3-5x. 6 strategies = 60-80% savings. MCP+A2A = framework-agnostic. Sarvam free for India.

# %% [markdown]
# <a href="https://colab.research.google.com/github/netsetos/genai-engg-course-learners/blob/main/module-09-ai-agents/lesson-9.9-long-running-async-agents/notebooks/exercises-9.9.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 9.9 Long-Running Async Agents
# Netsetos GenAI v2.0

# %%
print('Lesson 9.9: Long-Running Async Agents')

# %% [markdown]
# ## Framework Comparison

# %%
for fw,model,best in [('Temporal','Workflow-as-code','Enterprise scale'),('Inngest','Step functions','Serverless simplicity'),('LangGraph','Graph checkpoints','LangChain native'),('DBOS','Postgres-only','Minimal infra'),('Restate','Journal replay','Serverless/Lambda')]:
    print(f'  {fw:12s}: {model:20s} | {best}')

# %% [markdown]
# ## Serverless Limits

# %%
for svc,limit in [('Cloud Run Jobs','7 days (168 hours)'),('Azure Durable Functions','Unlimited'),('AWS Lambda','15 minutes'),('Step Functions','1 year (orchestrator)')]:
    print(f'  {svc:25s}: {limit}')

# %% [markdown]
# ---
# ## Recap
# Durable execution > task queues for stateful agents. Step memoization saves LLM tokens. SSE for streaming. At-least-once + idempotent = effectively-once. India = cheapest cloud. DPDP by May 2027.

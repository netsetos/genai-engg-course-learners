# %% [markdown]
# <a href="https://colab.research.google.com/github/netsetos/genai-engg-course-learners/blob/main/module-09-ai-agents/lesson-9.4-memory-systems/notebooks/exercises-9.4.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lesson 9.4 — Memory Systems
# Netsetos GenAI v2.0

# %%
print('Lesson 9.4: Memory Systems')

# %% [markdown]
# ## Context Windows 2026

# %%
for m,c,e in [('Claude 4.6','1M','~650K'),('GPT-5.4','272K','~180K'),('Gemini 2.5','1M','~650K')]:
    print(f'  {m}: {c} advertised, {e} effective')

# %% [markdown]
# ## Framework Comparison

# %%
for f,a,t in [('Mem0','66.9%','1800'),('Zep','63.8% LME','efficient'),('Letta','~83%','higher')]:
    print(f'  {f}: {a} accuracy, ~{t} tokens')

# %% [markdown]
# ## Prompt Caching

# %%
for p,d in [('Anthropic','90%'),('OpenAI','50%'),('Google','75%')]:
    print(f'  {p}: {d} discount on cached reads')

# %% [markdown]
# ## DPDP Requirements

# %%
for r,d in [('Consent','Active opt-in'),('Erasure','7-day response'),('Penalties','250 Cr')]:
    print(f'  {r}: {d}')

# %% [markdown]
# ---
# ## Recap
# Effective context ~65-70%. Compaction: lossless first. Mem0/Zep/Letta/LangGraph Store. CLAUDE.md != MEMORY.md. Graphs for multi-hop. DPDP: 7-day erasure. India: bge-multilingual-gemma2.
